# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/manpreetkaurbilkhu/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# %cd /content
# !git clone https://github.com/manpreetkaurbilkhu/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# !ls
# Out:
# /content
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 129 (delta 43), reused 92 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 1.85 MiB | 8.27 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
# !find . -maxdepth 2 -type d
# Out:
# .
# ./submission
# ./data
# ./data/raw
# ./work
# ./work/notebooks
# ./outputs
# ./outputs/charts
# ./.git
# ./.git/objects
# ./.git/info
# ./.git/refs
# ./.git/branches
# ./.git/logs
# ./.git/hooks
# ./notebooks
# ./skills
# ./skills/auditing-signals
# ./skills/writing-research-papers
# ./skills/hunting-leakage-and-validating
# ./skills/directing-your-ai-assistant
# ./skills/framing-ml-problems
# ./skills/training-honest-models
# ./skills/writing-data-contracts
# ./skills/writing-honest-claims
# ./skills/deploying-static-pages
# ./skills/querying-big-datasets
# ./skills/building-baselines
# ./skills/flyrank
# ./.github
# ./.github/workflows
# ./docs
# ./scripts

# %%
# !find work/notebooks -name "w03_data_contract.ipynb"
# Out:
# work/notebooks/w03_data_contract.ipynb

# %%
# !python - <<'PY'
import json

with open("work/notebooks/w03_data_contract.ipynb", "r", encoding="utf-8") as f:
    nb = json.load(f)

for i, cell in enumerate(nb["cells"]):
    if cell["cell_type"] == "code":
        print(f"\n--- Code Cell {i} ---")
        print("".join(cell["source"])[:500])
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
#
# --- Code Cell 2 ---
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# --- Code Cell 4 ---
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# --- Code Cell 6 ---
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#
#
# --- Code Cell 8 ---
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Unit of Analysis

# One row represents one content item (page) for one monthly snapshot of historical search performance.

# Time Window

# The features describe information available before the prediction point for that monthly snapshot. Future information is excluded from the model to prevent data leakage.

# Prediction Moment

# At the prediction time, only historical metrics are available. The model uses those historical features to estimate future ranking performance.

# Output

# The analysis produces a ranking score (CTR proxy) for each content item so that pages can be prioritized for optimization or content refresh.
# Verification check
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
df.head()
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
### Features
# - impressions_90d
# - clicks_90d
# - ctr
# - avg_position
# - content_type

# ### Label / Proxy
# - is_declining_label

# ### Context
# - content_id
# - client_id

# ### Excluded
# - trend_direction (derived from trend_pct)
# - trend_pct (used to create the label)
# - Any future information

# Reason: These fields would cause data leakage or are identifiers that should not be used as model features.

# Verify the selected fields exist
fields = [
    "search_volume",
    "competition",
    "cpc",
    "content_type",
    "main_intent",
    "word_count",
    "char_count",
    "ctr",
    "avg_position",
    "engagement_rate",
    "scroll_rate",
    "ai_traffic_pct",
    "trend_direction",
    "trend_pct",
    "content_id",
    "client_id"
]

print(df[fields].head())
# Out:
#    search_volume  competition   cpc     content_type    main_intent  \
# 0           10.0         0.67  2.05  keyword article  transactional
# 1           90.0         0.01  0.05  keyword article  informational
# 2            0.0         0.00  0.00  keyword article  informational
# 3           10.0         0.00  0.00  keyword article     commercial
# 4            0.0         0.00  0.00  keyword article  informational
#
#    word_count  char_count   ctr  avg_position  engagement_rate  scroll_rate  \
# 0      3221.0     20457.0  0.76          10.6             5.88         4.55
# 1      2481.0     15562.0  0.05          20.3             0.00        10.00
# 2      3515.0     23643.0  0.09          36.5             0.00        28.57
# 3         NaN         NaN  0.49           6.2             1.28         3.45
# 4      2803.0     17469.0  0.13          44.0             0.00        24.29
#
#    ai_traffic_pct trend_direction  trend_pct            content_id  \
# ...

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Missing Values

# Some fields contain missing values that are not random.

# - `word_count` has missing values for some content.
# - `char_count` also contains missing values.
# - Missing values may depend on `content_type`, so they should not automatically be replaced with 0.
# - Instead, missing-value indicators or appropriate imputation strategies should be considered after investigating the pattern.

# Verification is performed below.
# Missing values in every column

missing = df.isnull().sum().sort_values(ascending=False)
missing = missing[missing > 0]

print(missing)
# Out:
# provider_used        21438
# word_count            7699
# char_count            7699
# word_count_tier       7699
# char_count_tier       7699
# model_used            5733
# trend_pct             3388
# competition_level     2610
# search_volume         2468
# cpc                   2468
# competition           2468
# main_intent           2374
# scroll_rate            125
# dtype: int64

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Output

# The final output of this analysis is a ranked list of content pages with their predicted ranking trend.

# This output helps identify pages that should be refreshed or prioritized for optimization while ensuring that only historical information is used for prediction.

# Display a few important output columns

output_cols = [
    "content_id",
    "client_id",
    "ctr",
    "avg_position",
    "trend_direction"
]

df[output_cols].head()
# Out:
#              content_id          client_id   ctr  avg_position trend_direction
# 0  content_304f48230142  client_f369cb89fc  0.76          10.6            down
# 1  content_a1fb4e703a9e  client_4e07408562  0.05          20.3            down
# 2  content_9aa793d4d895  client_7f2253d7e2  0.09          36.5            down
# 3  content_331d6c4de07b  client_19581e27de  0.49           6.2          stable
# 4  content_d99b7a2d90ca  client_3fdba35f04  0.13          44.0            down

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
