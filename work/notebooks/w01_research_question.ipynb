# %% [markdown]
# <a href="https://colab.research.google.com/github/manpreetkaurbilkhu/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/manpreetkaurbilkhu/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# # My Lane

# I chose the Ranking Signal Analysis lane because I want to investigate which measurable page characteristics are associated with stronger search performance. The goal is to identify patterns that may help prioritize SEO decisions using data. This project focuses on supporting decision-making rather than explaining or predicting how search engine algorithms work.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# The Question

# ## Research Question
# Which page-level features are most strongly associated with better search performance in the available dataset?

# ## Decision
# Which pages should be prioritized for optimization based on their current signals?

# ## Unit of Analysis
# An individual web page.

# ## Output
# A ranked list or prediction showing which pages have stronger or weaker ranking-related signals.

# ## Action
# An SEO team can use these insights to prioritize pages for content updates, technical improvements, or further investigation.

# ## Cost of a Wrong Recommendation
# If the recommendations are incorrect, time and effort may be spent optimizing pages with limited improvement potential while better opportunities are missed.

# ## Why Machine Learning?
# Search performance depends on multiple interacting features. Machine learning can identify useful patterns across these features more effectively than manually inspecting each one.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Ensure the file 'content_refresh_anonymized.csv' is uploaded to your Colab environment.
# If you upload it directly to the '/content/' directory, use the following path:
df = pd.read_csv("/content/content_refresh_anonymized.csv")

# If the file is in a different location, please update the path accordingly.
# For example, if it's in a 'data' folder at the root: df = pd.read_csv("/content/data/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Average CTR:", df["ctr"].mean())
print("Average Position:", df["avg_position"].mean())
# Quick Look at the Data

# The starter dataset contains **30,000** pages with **44** features.

# The average click-through rate (CTR) is **0.5107** (approximately **51.07%**), and the average search position is **16.34**.

# These statistics show that the dataset contains a substantial number of pages and a diverse set of ranking-related features. The variation in CTR and average search position makes this dataset suitable for investigating relationships between page characteristics and observed search performance. These observations support my choice of the **Ranking Signal Analysis** lane for the capstone project.
# Out:
# Rows: 30000
# Columns: 44
# Average CTR: 0.5107333333333334
# Average Position: 16.342380000000002

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Careful Words

# This project analyzes patterns observed in the provided anonymized dataset.

# The results may help support SEO decision-making, but they do not prove how search engine ranking algorithms work or establish causal relationships.

# Any conclusions will be presented as observed associations within this dataset only.

# %% [markdown]
# First, we need to get the direct raw link to the CSV file on GitHub. Based on the previous error and the repository structure, it's likely located at:
#
# `https://raw.githubusercontent.com/manpreetkaurbilkhu/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv`
#
# We will use this link to download the file into your Colab environment.

# %%
# Download the CSV file directly from GitHub
# !wget -O /content/content_refresh_anonymized.csv https://raw.githubusercontent.com/manpreetkaurbilkhu/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv

# Verify the file has been downloaded
# !ls -l /content/content_refresh_anonymized.csv
# Out:
# --2026-07-27 16:20:27--  https://raw.githubusercontent.com/manpreetkaurbilkhu/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6727670 (6.4M) [text/plain]
# Saving to: ‘/content/content_refresh_anonymized.csv’
#
# /content/content_re 100%[===================>]   6.42M  17.9MB/s    in 0.4s
#
# 2026-07-27 16:20:29 (17.9 MB/s) - ‘/content/content_refresh_anonymized.csv’ saved [6727670/6727670]
#
# -rw-r--r-- 1 root root 6727670 Jul 27 16:20 /content/content_refresh_anonymized.csv

# %% [markdown]
# Now that the file is downloaded to `/content/content_refresh_anonymized.csv`, I will update the code in cell `V-HM_3dPSzNm` to load it from this path. Please run cell `V-HM_3dPSzNm` after this cell executes to load the dataset.

# %%
import os

# List files in the current working directory
print("Files in current directory:")
for root, dirs, files in os.walk('.'):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Files in current directory:
# ./.config/default_configs.db
# ./.config/config_sentinel
# ./.config/.last_survey_prompt.yaml
# ./.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# ./.config/gce
# ./.config/.last_opt_in_prompt.yaml
# ./.config/.last_update_check.json
# ./.config/active_config
# ./.config/logs/2026.06.04/13.32.18.735754.log
# ./.config/logs/2026.06.04/13.32.02.654775.log
# ./.config/logs/2026.06.04/13.32.39.344962.log
# ./.config/logs/2026.06.04/13.31.42.499627.log
# ./.config/logs/2026.06.04/13.32.38.346437.log
# ./.config/logs/2026.06.04/13.32.21.210570.log
# ./.config/configurations/config_default
# ./sample_data/README.md
# ./sample_data/anscombe.json
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/mnist_test.csv

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
